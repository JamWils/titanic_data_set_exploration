# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
file_path = os.getenv("DATASET_PATH")
df = pd.read_csv(os.path.join(file_path, 'CarPrice_Assignment.csv'))

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
X
# Out:
# <Axes: >

# %%
df['fueltype'].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df['cylindernumber'].value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64

# %%
cylinder_map = {
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'eight': 8,
    'twelve': 12
}

df['cylindernumber'] = df['cylindernumber'].map(cylinder_map)
df['cylindernumber'].value_counts()
# Out:
# cylindernumber
# 4     159
# 6      24
# 5      11
# 8       5
# 2       4
# 3       1
# 12      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    int64
# ...

# %%
object_type = pd.get_dummies(df[['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'fuelsystem', 'enginetype']], drop_first=True)
object_type.head()
# Out:
#    fueltype_gas  aspiration_turbo  doornumber_two  carbody_hardtop  \
# 0          True             False            True            False
# 1          True             False            True            False
# 2          True             False            True            False
# 3          True             False           False            False
# 4          True             False           False            False
#
#    carbody_hatchback  carbody_sedan  carbody_wagon  drivewheel_fwd  \
# 0              False          False          False           False
# 1              False          False          False           False
# 2               True          False          False           False
# 3              False           True          False            True
# 4              False           True          False           False
#
#    drivewheel_rwd  enginelocation_rear  ...  fuelsystem_mfi  fuelsystem_mpfi  \
# 0            True                False  ...           False             True
# ...

# %%
df_clean = pd.concat([df.drop(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'fuelsystem', 'enginetype'], axis=1), object_type], axis=1)

# %%
df_clean.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    cylindernumber  enginesize  boreratio  ...  fuelsystem_mfi  \
# 0               4         130       3.47  ...           False
# 1               4         130       3.47  ...           False
# 2               6         152       2.68  ...           False
# 3               4         109       3.19  ...           False
# 4               5         136       3.19  ...           False
#
#    fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi  enginetype_dohcv  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_ID               205 non-null    int64
#  1   symboling            205 non-null    int64
#  2   wheelbase            205 non-null    float64
#  3   carlength            205 non-null    float64
#  4   carwidth             205 non-null    float64
#  5   carheight            205 non-null    float64
#  6   curbweight           205 non-null    int64
#  7   cylindernumber       205 non-null    int64
#  8   enginesize           205 non-null    int64
#  9   boreratio            205 non-null    float64
#  10  stroke               205 non-null    float64
#  11  compressionratio     205 non-null    float64
#  12  horsepower           205 non-null    int64
#  13  peakrpm              205 non-null    int64
#  14  citympg              205 non-null    int64
# ...

# %%
features = ['enginesize', 'horsepower', 'cylindernumber', 'curbweight', 'citympg', 'highwaympg', 'compressionratio', 'stroke']
fig, axes = plt.subplots(2, 4, figsize=(20, 8))
axes = axes.flatten()
    
for i, feature in enumerate(features):
    sns.scatterplot(data=df_clean, x=feature, y='price', ax=axes[i])
    axes[i].set_title(f'{feature} vs price')

plt.tight_layout()
plt.show()

# %%
features = ['carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'horsepower', 'citympg', 'highwaympg', 'compressionratio', 'stroke']
fig, axes = plt.subplots(2, 5, figsize=(25, 8))
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.scatterplot(data=df_clean, x=feature, y='price', ax=axes[i])
    axes[i].set_title(f'{feature} vs price')

plt.tight_layout()
plt.show()

# %%
features = ['peakrpm', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'fuelsystem']
fig, axes = plt.subplots(3, 3, figsize=(20, 15))
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.scatterplot(data=df, x=feature, y='price', ax=axes[i])
    axes[i].set_title(f'{feature} vs price')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Training Sets

# %%
from sklearn.model_selection import train_test_split

# %%
x = df_clean[['carlength', 'carwidth', 'curbweight', 'enginesize', 'horsepower']]
y = df_clean['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
X_train.head()
# Out:
#      carlength  carwidth  curbweight  enginesize  horsepower
# 90       165.3      63.8        2017         103          55
# 173      175.6      66.5        2326         122          92
# 93       170.2      63.8        2024          97          69
# 5        177.3      66.3        2507         136         110
# 167      176.2      65.6        2540         146         116

# %%
y_train.head()
# Out:
# 90      7099.0
# 173     8948.0
# 93      7349.0
# 5      15250.0
# 167     8449.0
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Coef: ", model.coef_)
# Out:
# Coef:  [-12.8091212  649.7147003    2.17127486  76.8791357   57.7121021 ]

# %%
prediction = model.predict(X_test)

# %%
plt.scatter(y_test, prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn import metrics

print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, prediction))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test, prediction))
print("Root Mean Squared Error: ", metrics.root_mean_squared_error(y_test, prediction))
# Out:
# Mean Absolute Error:  2599.529089396439
# Mean Squared Error:  13117024.158833206
# Root Mean Squared Error:  3621.7432486073894
